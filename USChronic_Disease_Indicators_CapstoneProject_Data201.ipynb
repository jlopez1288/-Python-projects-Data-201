# %% [markdown]
# <a href="https://colab.research.google.com/github/jlopez1288/-Python-projects-Data-201/blob/main/USChronic_Disease_Indicators_CapstoneProject_Data201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **A brief analysis about Chronic Disease Indicators in the US**

# %% [markdown]
# **Introduction**
#
#
#
#
# I chose this project because I have an interest in health population and also because I work in healthcare.
# The goal of this project  is to analyze the chronic diseases indicators and risk factors in  the US population
# I am observing which CDI has the highest number compared to other diseases. It is very important because it can show the most prevalent numbers by location and gender.

# %% [markdown]
# **What are chronic diseases?** Chronic diseases are defined broadly as conditions that last 1 year or more and require ongoing medical attention or limit activities of daily living or both. Chronic diseases such as heart disease, cancer, and diabetes are the leading causes of death and disability in the United States. They are also leading drivers of the nation’s $4.1 trillion in annual health care costs.
# Source: About Chronic Diseases | CDC

# %% [markdown]
# **What are chronic disease indicators?**The chronic disease indicators (CDI) are a set of surveillance indicators developed by consensus among CDC, the Council of State and Territorial Epidemiologists (CSTE), and the National Association of Chronic Disease Directors (NACDD). CDI enables public health professionals and policymakers to retrieve uniformly defined state-level data for chronic diseases and risk factors that have a substantial impact on public health. These indicators are essential for surveillance, prioritization, and evaluation of public health interventions. More
# Source: https://www.cdc.gov/cdi/overview.html

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go # To Generate Graphs
import plotly.express as px # To Generate box plot for statistical representation
# %matplotlib inline
import plotly.express as px
CDI=pd.read_csv('https://query.data.world/s/5uk4zfshuhntgzhbsaeyvz4jun7tno')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7,19,20,21,22,26,27,30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
CDI= pd.read_csv('https://query.data.world/s/5uk4zfshuhntgzhbsaeyvz4jun7tno')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7,19,20,21,22,26,27,30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# **View Data**

# %%
CDI
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# ...

# %% [markdown]
# **How many rows and columns?**

# %%
CDI.shape
# Out:
# (237961, 34)

# %% [markdown]
# **Testing if the object has the right type of data in it. Syntax: CDI.head(self, n=5)**

# %%
CDI.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2013     2013           CA            California      YRBSS  Alcohol
# 1       2013     2013           CO              Colorado      YRBSS  Alcohol
# 2       2013     2013           CT           Connecticut      YRBSS  Alcohol
# 3       2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 4       2013     2013           DE              Delaware      YRBSS  Alcohol
#
#                   Question Response DataValueUnit DataValueTypeID  ...  \
# 0  Alcohol use among youth      NaN             %         CrdPrev  ...
# 1  Alcohol use among youth      NaN             %         CrdPrev  ...
# 2  Alcohol use among youth      NaN             %         CrdPrev  ...
# 3  Alcohol use among youth      NaN             %         CrdPrev  ...
# 4  Alcohol use among youth      NaN             %         CrdPrev  ...
#
#   TopicID QuestionID  ResponseID LocationID StratificationCategoryID1  \
# ...

# %% [markdown]
# **Column names**

# %%
CDI.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueTypeID',
#        'DataValueType', 'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'TopicID', 'QuestionID', 'ResponseID', 'LocationID',
#        'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %% [markdown]
# **Prepare data**

# %% [markdown]
# **Number of topics within dataset**/CDI About 19 topics in total

# %%
CDI.Topic.value_counts()
# Out:
# Cardiovascular Disease                             43835
# Diabetes                                           37226
# Chronic Obstructive Pulmonary Disease              32704
# Overarching Conditions                             21569
# Asthma                                             18371
# Alcohol                                            15436
# Nutrition, Physical Activity, and Weight Status    14364
# Arthritis                                          12620
# Tobacco                                            11262
# Cancer                                              7001
# Chronic kidney disease                              6135
# Oral Health                                         5213
# Older Adults                                        3289
# Mental Health                                       2610
# Chronic Kidney Disease                              2058
# Immunization                                        1850
# ...

# %% [markdown]
# **Cleaning dataset: Dropping columns or adding?**
# -Dropping columns that are not needed for the analysis

# %%
CDI.drop(columns=['Response','DataValueFootnoteSymbol','DatavalueFootnote'])
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# ...

# %% [markdown]
# **Check data after dropping columns**

# %%
CDI.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2013     2013           CA            California      YRBSS  Alcohol
# 1       2013     2013           CO              Colorado      YRBSS  Alcohol
# 2       2013     2013           CT           Connecticut      YRBSS  Alcohol
# 3       2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 4       2013     2013           DE              Delaware      YRBSS  Alcohol
#
#                   Question Response DataValueUnit DataValueTypeID  ...  \
# 0  Alcohol use among youth      NaN             %         CrdPrev  ...
# 1  Alcohol use among youth      NaN             %         CrdPrev  ...
# 2  Alcohol use among youth      NaN             %         CrdPrev  ...
# 3  Alcohol use among youth      NaN             %         CrdPrev  ...
# 4  Alcohol use among youth      NaN             %         CrdPrev  ...
#
#   TopicID QuestionID  ResponseID LocationID StratificationCategoryID1  \
# ...

# %%
CDI.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                      object
# DataValueUnit                 object
# DataValueTypeID               object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# StratificationCategory3       object
# Stratification3               object
# GeoLocation                   object
# TopicID                       object
# ...

# %%
CDI.Stratification1.value_counts()
# Out:
# Overall                             44557
# Female                              29314
# Male                                29313
# White, non-Hispanic                 26956
# Black, non-Hispanic                 26956
# Hispanic                            26956
# Other, non-Hispanic                 16462
# Multiracial, non-Hispanic           16462
# Asian or Pacific Islander           10494
# American Indian or Alaska Native    10491
# Name: Stratification1, dtype: int64

# %%
list= ['Female','Male']

# %%
CDI.Stratification1.unique()
# Out:
# array(['Overall', 'Male', 'Female', 'White, non-Hispanic',
#        'Black, non-Hispanic', 'Hispanic', 'Other, non-Hispanic',
#        'Multiracial, non-Hispanic', 'Asian or Pacific Islander',
#        'American Indian or Alaska Native'], dtype=object)

# %%
CDI.DataValueType.unique()
# Out:
# array(['Crude Prevalence',
#        'Local control of the regulation of alcohol outlet density',
#        'Age-adjusted Prevalence', 'Number', 'Mean', 'Age-adjusted Mean',
#        'Crude Rate', 'Age-adjusted Rate', 'US Dollars',
#        'Per capita alcohol consumption',
#        'Commercial host (dram shop) liability status for alcohol service',
#        'Average Annual Number', 'Average Annual Age-adjusted Rate',
#        'Average Annual Crude Rate', 'Prevalence', 'Yes/No', 'Crude Mean',
#        'Percent', 'Median'], dtype=object)

# %%
CDI.describe()
# Out:
#            YearStart        YearEnd  DataValueAlt  LowConfidenceLimit  \
# count  237961.000000  237961.000000  1.659960e+05       141388.000000
# mean     2012.678254    2012.723833  9.659927e+02           60.392008
# std         1.367197       1.275515  1.884835e+04          102.967598
# min      2001.000000    2001.000000  0.000000e+00            0.000000
# 25%      2012.000000    2012.000000  2.020000e+01           13.000000
# 50%      2013.000000    2013.000000  4.830000e+01           34.100000
# 75%      2014.000000    2014.000000  8.500000e+01           63.600000
# max      2014.000000    2014.000000  4.022808e+06         1293.000000
#
#        HighConfidenceLimit
# count        141388.000000
# mean             74.255692
# std             119.295383
# min               0.490000
# 25%              19.700000
# 50%              48.600000
# 75%              77.100000
# max            2088.000000

# %%
CDI.Topic.value_counts()
# Out:
# Cardiovascular Disease                             43835
# Diabetes                                           37226
# Chronic Obstructive Pulmonary Disease              32704
# Overarching Conditions                             21569
# Asthma                                             18371
# Alcohol                                            15436
# Nutrition, Physical Activity, and Weight Status    14364
# Arthritis                                          12620
# Tobacco                                            11262
# Cancer                                              7001
# Chronic kidney disease                              6135
# Oral Health                                         5213
# Older Adults                                        3289
# Mental Health                                       2610
# Chronic Kidney Disease                              2058
# Immunization                                        1850
# ...

# %%
CDI.Topic.unique()
# Out:
# array(['Alcohol', 'Asthma', 'Arthritis', 'Cancer',
#        'Chronic kidney disease', 'Chronic Kidney Disease',
#        'Chronic Obstructive Pulmonary Disease', 'Cardiovascular Disease',
#        'Cardiovascular disease', 'Diabetes', 'Tobacco', 'Disability',
#        'Immunization', 'Mental Health',
#        'Nutrition, Physical Activity, and Weight Status', 'Oral Health',
#        'Older Adults', 'Overarching Conditions', 'Reproductive Health'],
#       dtype=object)

# %% [markdown]
# **Main top chronic diseases indicators:** Alcohol, Cancer, Cardiovascular Disease, Diabetes, Physical Activity and Weight Status, Older Adults.

# %%
CDI.Topic.value_counts().plot(kind='bar')
plt.title('Chronic Diseases Chart',fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('Chronic disease')

# %% [markdown]
# **Cardiovascular disease leads overall, diabetes falls in the second place and COPD as the 3rd place.**

# %%
CDI.Stratification1.unique()
# Out:
# array(['Overall', 'Male', 'Female', 'White, non-Hispanic',
#        'Black, non-Hispanic', 'Hispanic', 'Other, non-Hispanic',
#        'Multiracial, non-Hispanic', 'Asian or Pacific Islander',
#        'American Indian or Alaska Native'], dtype=object)

# %%
CDI.Stratification1.value_counts()
# Out:
# Overall                             44557
# Female                              29314
# Male                                29313
# White, non-Hispanic                 26956
# Black, non-Hispanic                 26956
# Hispanic                            26956
# Other, non-Hispanic                 16462
# Multiracial, non-Hispanic           16462
# Asian or Pacific Islander           10494
# American Indian or Alaska Native    10491
# Name: Stratification1, dtype: int64

# %%
CDI.Stratification1.value_counts().plot(kind='bar')
plt.title('Demographics',fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('Demographics')

# %% [markdown]
# Female population slightly over men in this graph
# White non-Hispanic shows higher numbers than the rest of the population.

# %%
CDI.LocationDesc.value_counts()
# Out:
# Florida                 4584
# Kentucky                4583
# New Jersey              4583
# Nebraska                4583
# New York                4583
# North Carolina          4583
# South Carolina          4583
# Nevada                  4583
# Arizona                 4582
# Wisconsin               4582
# Iowa                    4582
# Vermont                 4579
# Oregon                  4538
# South Dakota            4538
# New Mexico              4538
# Hawaii                  4538
# Washington              4538
# West Virginia           4538
# Michigan                4537
# Colorado                4537
# Arkansas                4537
# Texas                   4433
# Utah                    4433
# Virginia                4433
# Rhode Island            4433
# Pennsylvania            4433
# Oklahoma                4433
# Ohio                    4433
# Wyoming                 4433
# Tennessee               4433
# New Hampshire           4433
# North Dakota            4433
# ...

# %%
CDI.LocationDesc.value_counts().plot(kind='bar')
plt.title('States',fontsize = 16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
plt.savefig('States')

# %% [markdown]
# **Florida leads in numbers of CDI indicators compared to New York State**

# %%
CDI_heart = CDI[(CDI['Topic'] == 'Cardiovascular Disease')]
CDI_heart
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 82952        2013     2013           KY     Kentucky       NVSS
# 83105        2010     2010           AZ      Arizona       NVSS
# 83173        2010     2010           OK     Oklahoma       NVSS
# 83461        2010     2010           CA   California       NVSS
# 83581        2012     2012           WI    Wisconsin       NVSS
# ...           ...      ...          ...          ...        ...
# 139756       2014     2014           WY      Wyoming      BRFSS
# 139757       2014     2014           WY      Wyoming      BRFSS
# 139758       2014     2014           WY      Wyoming      BRFSS
# 139759       2014     2014           WY      Wyoming      BRFSS
# 139760       2014     2014           WY      Wyoming      BRFSS
#
#                          Topic  \
# 82952   Cardiovascular Disease
# 83105   Cardiovascular Disease
# 83173   Cardiovascular Disease
# 83461   Cardiovascular Disease
# 83581   Cardiovascular Disease
# ...

# %% [markdown]
# **Florida is the has the highest numbers of CDI's**

# %%
CDI_gender= CDI.loc[CDI['Stratification1'].isin(['Male', 'Female'])]
CDI
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# ...

# %% [markdown]
# **Findings and conclusion**
#
#
# *   Preparing this dataset was complex  because there was a list of several dataset that interlapped with the research
# *   I found out that cardiovascular disease is the leading chronic disease in the US.
#
# *  Where Florida State shows in the top of the list and that women have the highest number of prevalence of CDI's.
# *   A very interesting finding was that COPD surpassed cancer and chronic kidney disease where I expected for cancer to be as one of the top 5 chronic diseases in the US.
#
# Lack of activities, poor nutrition tobacco use and excessive ingestion of alcohol can trigger to have a higher prevalence to develop a chronic disease: especially cardiovascular disease.
