# %% [markdown]
# <a href="https://colab.research.google.com/github/jlopez1288/-Python-projects-Data-201/blob/main/NYCSchools_Student__testperformance_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install geopandas
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **LIBRARIES**

# %%
##import tools: NumPy for Advanced linear algebra, Matplotlib for Visualization and data plotting, Pandas for Data manipulation and analysis, Geopandas for programming geospatial data in python,  matplotlib.pyplot for plotting map
#folium for map visuals
import geopandas as gpd
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as py
from shapely.geometry import Point
import matplotlib
import folium 
from time import sleep

# %% [markdown]
# **OBJECTIVES**
#
#
# *   Analyze student test performance
# *   Pick a school in the data as an initial point
# *   Pick a feature/measure/score
# *   Compare above school to schools in the entire dataset within a Borough/District
# *   Descriptive Statistics
# *   Cleaning tasks
# *   Visualization
# *   Conclusion

# %% [markdown]
# **Read the data**

# %%
missing_values=['s','naN', 'NaN','--','na']

# %%
#Imported data ( CSV> dataframe)
url= 'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv'
Schools= pd.read_csv(url)

# %%
Schools
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# **Info about my dataset**

# %%
#Rows & Columns of Schools Dataset
Schools.shape
# Out:
# (212331, 15)

# %%
Schools.head(15)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
#
# ...

# %% [markdown]
# .head() method returns back the first 5 rows. You can adjust the number of rows to get back if you want forexample .head(15)

# %%
Schools.tail(15)
# Out:
#        School DBN                    School Name School Level  \
# 212316     84X706  Harriet Tubman Charter School          K-8
# 212317     84X706  Harriet Tubman Charter School          K-8
# 212318     84X717           Icahn Charter School          K-8
# 212319     84X717           Icahn Charter School          K-8
# 212320     84X717           Icahn Charter School          K-8
# 212321     84X717           Icahn Charter School          K-8
# 212322     84X717           Icahn Charter School          K-8
# 212323     84X717           Icahn Charter School          K-8
# 212324     84X717           Icahn Charter School          K-8
# 212325     84X717           Icahn Charter School          K-8
# 212326     84X717           Icahn Charter School          K-8
# 212327     84X717           Icahn Charter School          K-8
# 212328     84X717           Icahn Charter School          K-8
# 212329     84X717           Icahn Charter School          K-8
# ...

# %%
Schools.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
Schools.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
Schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %% [markdown]
# **Descriptive Stats**

# %%
Schools.describe
# Out:
# <bound method NDFrame.describe of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
Schools.groupby(['School Level','School Name','Regents Exam','Percent Scoring 80 or Above', 'Year']).count()
# Out:
#                                                                                                                        School DBN  \
# School Level     School Name                             Regents Exam                Percent Scoring 80 or Above Year
# Elementary       Imagine Me Leadership Charter School    Living Environment          0                           2017           3
#                                                                                      s                           2016           6
#                                                                                                                  2017           4
#                  P.S. 111 Adolph S. Ochs                 Common Core Algebra         s                           2015           7
#                  P.S. 202 Ernest S. Jenkyns              Living Environment          s                           2015           5
# ...

# %%
Schools.groupby([ 'School Level', 'Regents Exam', 'Year', 'Mean Score', 'Number Scoring Below 65', 'Number Scoring 65 or Above', 'Number Scoring 80 or Above']).count()
# Out:
#                                                                                                                                             School DBN  \
# School Level     Regents Exam                Year Mean Score Number Scoring Below 65 Number Scoring 65 or Above Number Scoring 80 or Above
# Elementary       Common Core Algebra         2015 s          s                       s                          s                                    7
#                  Living Environment          2015 s          s                       s                          s                                    5
#                                              2016 s          s                       s                          s                                    6
#                                              2017 67.8       6                       12                         0                                    3
# ...

# %%
Schools.groupby(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year', 'Mean Score', 'Number Scoring Below 65', 'Number Scoring 65 or Above', 'Number Scoring 80 or Above']).mean()
# Out:
#                                                                                                                                                                                   Total Tested
# School DBN School Name                    School Level Regents Exam                Year Mean Score Number Scoring Below 65 Number Scoring 65 or Above Number Scoring 80 or Above
# 01M034     P.S. 034 Franklin D. Roosevelt K-8          Common Core Algebra         2017 s          s                       s                          s                               2.222222
#                                                        Living Environment          2015 75.5       1                       5                          3                               6.000000
#                                                                                         77.9       1                       15                         7                              16.000000
# ...

# %%
Schools.groupby(['School Name', 'School Level', 'Regents Exam', 'Year', 'Mean Score', 'Number Scoring Below 65', 'Number Scoring 65 or Above', 'Number Scoring 80 or Above']).mean()
# Out:
#                                                                                                                                                                                                Total Tested
# School Name                                        School Level     Regents Exam                Year Mean Score Number Scoring Below 65 Number Scoring 65 or Above Number Scoring 80 or Above
# 47 The American Sign Language and English Secondar High school      Algebra2/Trigonometry       2015 47.6       6                       3                          1                                   9.00
#                                                                                                      53         9                       5                          1                                  14.00
# ...

# %%
Schools.groupby([ 'School Name',  'Regents Exam', 'Year', 'Mean Score', 'Number Scoring Below 65', 'Number Scoring 65 or Above', 'Number Scoring 80 or Above']).count()
# Out:
#                                                                                                                                                                               School DBN  \
# School Name                                        Regents Exam                Year Mean Score Number Scoring Below 65 Number Scoring 65 or Above Number Scoring 80 or Above
# 47 The American Sign Language and English Secondar Algebra2/Trigonometry       2015 47.6       6                       3                          1                                    1
#                                                                                     53         9                       5                          1                                    2
#                                                                                     s          s                       s                          s                                    6
# ...

# %%
Schools.info
# Out:
# <bound method DataFrame.info of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
Schools.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
Schools.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
#Renaming dataset
Schools.rename(columns={'School DBN': 'School_DBN','School Name': 'School_Name','School Level': 'School_Level','Regents Exam': 'Regents_Exam','Year': 'Year_','Total Tested': 'Total_Tested','Mean Score': 'Mean_Score','Number Scoring Below 65': 'Number_Scoring_Below_65','Percent Scoring Below 65' :'Percent_Scoring_Below_65','Number Scoring 65 or Above': 'Number_Scoring_65_or_Above','Percent Scoring 65 or Above': 'Percent_Scoring_65_or_Above','Number Scoring 80 or Above': 'Number_Scoring_80_or_Above', 'Percent Scoring 80 or Above': 'Percent_Scoring_80_or_Above', 'Number Scoring CR': 'Number_Scoring_CR','Percent Scoring CR': 'Percent_Scoring_CR'}
# Out:
#   File "<ipython-input-24-5da6dea801c3>", line 2
#     Schools.rename(columns={'School DBN': 'School_DBN','School Name': 'School_Name','School Level': 'School_Level','Regents Exam': 'Regents_Exam','Year': 'Year_','Total Tested': 'Total_Tested','Mean Score': 'Mean_Score','Number Scoring Below 65': 'Number_Scoring_Below_65','Percent Scoring Below 65' :'Percent_Scoring_Below_65','Number Scoring 65 or Above': 'Number_Scoring_65_or_Above','Percent Scoring 65 or Above': 'Percent_Scoring_65_or_Above','Number Scoring 80 or Above': 'Number_Scoring_80_or_Above', 'Percent Scoring 80 or Above': 'Percent_Scoring_80_or_Above', 'Number Scoring CR': 'Number_Scoring_CR','Percent Scoring CR': 'Percent_Scoring_CR'}
# ...

# %%
Schools.isnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0              False       False                    False
# ...

# %%
Schools.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
Schools['Number Scoring CR']= pd.to_numeric(Schools['Number Scoring CR'],errors='coerce')

# %%
Schools
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
missing_values= ["n/a", "na", "--"]

# %% [markdown]
# **DATA SOURCE**
#
# https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv
